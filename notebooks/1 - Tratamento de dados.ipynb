# %% [markdown]
# # **Tratamento de dados**
#
# ---

# %% [markdown]
# ### **1. Importações**

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn

# %%
base = pd.read_csv('../data/train.csv')
pd.set_option('display.max_columns', 150)
base.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# ...

# %% [markdown]
# ### **2. Verificando informações iniciais da base**

# %% [markdown]
# #### **Descrição das colunas**
# - **SalePrice** - preço de venda do imóvel em dólares. Esta é a variável alvo que você está tentando prever.
# - **MSSubClass** : A classe de construção
# - **MSZoning** : A classificação geral de zoneamento
# - **LotFrontage** : Pés lineares de rua conectada à propriedade
# - **LotArea** : Tamanho do lote em pés quadrados
# - **Street** : Tipo de rua
# - **Alley** : Tipo de beco de acesso
# - **LotShape** : Forma geral da propriedade
# - **LandContour** : Planicidade da propriedade
# - **Utilities** : Tipo de utilitários disponíveis
# - **LotConfig** : configuração do lote
# - **LandSlope** : Inclinação da propriedade
# - **Neighborhood** : Locais físicos dentro dos limites da cidade de Ames
# - **Condition** : Proximidade da estrada principal ou ferrovia
# - **Condition2** : Proximidade da estrada principal ou ferrovia (se uma segunda estiver presente)
# - **BldgType** : Tipo de moradia
# - **HouseStyle** : estilo de moradia
# - **GlobalQual** : Material geral e qualidade de acabamento
# - **OverCond** : Classificação geral da condição
# - **YearBuilt** : Data original de construção
# - **YearRemodAdd** : Data da remodelação
# - **RoofStyle** : Tipo de telhado
# - **RoofMatl** : Material do telhado
# - **Exterior1st** : Cobertura exterior da casa
# - **Exterior2** : Cobertura exterior da casa (se houver mais de um material)
# - **MasVnrType** : tipo de folheado de alvenaria
# - **MasVnrArea** : Área folheada de alvenaria em pés quadrados
# - **ExterQual** : Qualidade do material exterior
# - **ExterCond** : Condição atual do material no exterior
# - **Fundation** : Tipo de fundação
# - **BsmtQual** : Altura do porão
# - **BsmtCond** : Estado geral do porão
# - **BsmtExposure** : Paredes de porão no nível do jardim
# - **BsmtFinType1** : Qualidade da área acabada do porão
# - **BsmtFinSF1** : Pés quadrados acabados tipo 1
# - **BsmtFinType2** : Qualidade da segunda área acabada (se presente)
# - **BsmtFinSF2** : Tipo 2 pés quadrados acabados
# - **BsmtUnfSF** : Pés quadrados inacabados de área de subsolo
# - **TotalBsmtSF** : Total de pés quadrados de área do porão
# - **Heating** : Tipo de aquecimento
# - **HeatingQC** : Qualidade e condição do aquecimento
# - **CentralAir** : Ar condicionado central
# - **Electrical** : Sistema elétrico
# - **1stFlrSF** : pés quadrados do primeiro andar
# - **2ndFlrSF** : Pés quadrados do segundo andar
# - **LowQualFinSF** : Pés quadrados com acabamento de baixa qualidade (todos os andares)
# - **GrLivArea** : pés quadrados de área de estar acima do nível do solo (solo)
# - **BsmtFullBath** : Banheiros completos no porão
# - **BsmtHalfBath** : lavabos no subsolo
# - **FullBath** : Banheiros completos acima do nível do solo
# - **HalfBath** : Lavabos acima do nível do solo
# - **BedroomAbvGr** : Número de quartos acima do subsolo
# - **KitchenAbvGr** : Número de cozinhas
# - **KitchenQual** : Qualidade da cozinha
# - **TotRmsAbvGrd** : Total de quartos acima da categoria (não inclui banheiros)
# - **Functional** : classificação de funcionalidade doméstica
# - **Fireplaces** : Número de lareiras
# - **FireplaceQu** : Qualidade da lareira
# - **GarageType** : localização da garagem
# - **GarageYrBlt** : ano em que a garagem foi construída
# - **GarageFinish** : Acabamento interior da garagem
# - **GarageCars** : Tamanho da garagem em capacidade de carros
# - **GarageArea** : Tamanho da garagem em pés quadrados
# - **GarageQual** : Qualidade da garagem
# - **GarageCond** : condição da garagem
# - **PavedDrive** : entrada pavimentada
# - **WoodDeckSF** : Área do deck de madeira em pés quadrados
# - **OpenPorchSF** : área de varanda aberta em pés quadrados
# - **EnclosedPorch** : área de varanda fechada em pés quadrados
# - **3SsnPorch** : Área de varanda de três estações em pés quadrados
# - **ScreenPorch** : área da varanda com tela em pés quadrados
# - **PoolArea** : Área da piscina em pés quadrados
# - **PoolQC** : Qualidade da piscina
# - **Fence** : Qualidade da cerca
# - **MiscFeature** : recurso diverso não coberto em outras categorias
# - **MiscVal** : $Valor do recurso diverso
# - **MoSold** : mês vendido
# - **YrSold** : Ano de Venda
# - **SaleType** : Tipo de venda
# - **SaleCondition** : Condição de venda

# %% [markdown]
# #### **Descrição de alguns valores que serão analisados**
# - Po: Poor
# - Fa: Fair
# - TA: Typical/Average
# - Gd: Good
# - Ex: Excellent

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
base.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
base.drop('Id', axis=1).duplicated().sum()
# Out:
# np.int64(0)

# %%
base.nunique().sort_values(ascending=False).head(10)
# Out:
# Id             1460
# LotArea        1073
# GrLivArea       861
# BsmtUnfSF       780
# 1stFlrSF        753
# TotalBsmtSF     721
# SalePrice       663
# BsmtFinSF1      637
# GarageArea      441
# 2ndFlrSF        417
# dtype: int64

# %%
base.nunique().sort_values(ascending=True).head(10)
# Out:
# CentralAir      2
# Utilities       2
# Street          2
# Alley           2
# BsmtHalfBath    3
# LandSlope       3
# GarageFinish    3
# HalfBath        3
# MasVnrType      3
# PavedDrive      3
# dtype: int64

# %% [markdown]
# ### **3. Analisando as cinco categorias com mais valores nulos**

# %%
base.shape
# Out:
# (1460, 81)

# %%
base.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# MasVnrType      872
# dtype: int64

# %% [markdown]
# #### **3.1. PoolQC**

# %%
base.fillna({'PoolQC':'Nulo'}).groupby('PoolQC')['SalePrice'].agg(['mean','count','min','max','std'])
# Out:
#                  mean  count     min     max            std
# PoolQC
# Ex      490000.000000      2  235000  745000  360624.458405
# Fa      215500.000000      2  181000  250000   48790.367902
# Gd      201990.000000      3  160000  274970   63441.392639
# Nulo    180404.663455   1453   34900  755000   78168.872519

# %% [markdown]
# São apenas 7 casas que possuem piscina. Dificilmente o modelo consiguirá capturar esses padrões, por isso, vou excluir essa coluna

# %%
base = base.drop('PoolQC',axis=1)

# %% [markdown]
# #### **3.2. MiscFeature**

# %%
base.fillna({'MiscFeature':'Nulo'}).groupby('MiscFeature')['SalePrice'].agg(['mean','count','min','max','std'])
# Out:
#                       mean  count     min     max           std
# MiscFeature
# Gar2         170750.000000      2  151500  190000  27223.611076
# Nulo         182046.410384   1406   34900  755000  80084.136570
# Othr          94000.000000      2   55000  133000  55154.328933
# Shed         151187.612245     49   55993  277000  51642.728056
# TenC         250000.000000      1  250000  250000           NaN

# %% [markdown]
# - Explicações
#     - Gar2: Segunda garagem
#     - Shed: Galpão de armazenamento
#     - Othr: Outros itens adicionais que não estão especificados
#     - TenC: Quadra de tênis

# %%
base = base.drop('MiscFeature',axis=1)

# %% [markdown]
# #### **3.3. Alley**

# %%
base.fillna({'Alley':'Nulo'}).groupby('Alley')['SalePrice'].agg(['mean','count','min','max','std'])
# Out:
#                 mean  count    min     max           std
# Alley
# Grvl   122219.080000     50  52500  256000  34780.780734
# Nulo   183452.131483   1369  34900  755000  80667.145180
# Pave   168000.585366     41  40000  265979  38370.375243

# %%
import sys
sys.path.append("../functions/")
from funcoes import kde_violin
help(kde_violin)
# Out:
# Help on function kde_violin in module funcoes:
#
# kde_violin(dataframe, coluna, coluna_alvo, salvar_como=None)
#     Exibirá dois gráficos: KDE e Violino
#
#     dataframe ----> Base de dados
#     coluna -------> Coluna para se explorar
#     coluna_alvo --> Coluna target
#     salvar_como --> Nome do arquivo para salvar

# %%
kde_violin(base, 'Alley', 'SalePrice')

# %%
base = base.drop('Alley',axis=1)

# %% [markdown]
# #### **3.4. Fence**

# %%
base.fillna({'Fence':'Nulo'}).groupby('Fence')['SalePrice'].agg(['mean','count','min','max','std'])
# Out:
#                 mean  count     min     max           std
# Fence
# GdPrv  178927.457627     59  108000  475000  56757.237563
# GdWo   140379.314815     54   34900  381000  53592.585059
# MnPrv  148751.089172    157   40000  745000  66096.069463
# MnWw   134286.363636     11  110000  187000  21781.805376
# Nulo   187596.837998   1179   35311  755000  81656.497075

# %% [markdown]
# - Explicações
#     - GdPrv: Boa privacidade (Good Privacy)
#     - GdWo: Boa qualidade (Good Wood)
#     - MnPrv: Privacidade média (Minimum Privacy)
#     - MnWw: Privacidade média com madeira (Minimum Wood)

# %%
kde_violin(base, 'Fence', 'SalePrice')

# %%
base = base.drop("Fence",axis=1)

# %% [markdown]
# #### **3.5. MasVnrType**

# %%
base.fillna({'MasVnrType':'Nulo'}).groupby('MasVnrType')['SalePrice'].agg(['mean','count','min','max','std'])
# Out:
#                      mean  count     min     max           std
# MasVnrType
# BrkCmn      146318.066667     15   89471  277000  46187.583632
# BrkFace     204691.871910    445   75000  755000  81214.293554
# Nulo        156958.243119    872   34900  745000  61491.688969
# Stone       265583.625000    128  119000  611657  99940.156577

# %% [markdown]
# - Explicações
#     - BrkCmn: Bloco de cimento (Common Brick).
#     - BrkFace: Tijolo (Face Brick).
#     - Stone: Pedra.
#     - Stucco: Estuque.
#     - Other: Outros tipos de revestimento.

# %%
kde_violin(base, 'MasVnrType', 'SalePrice')

# %% [markdown]
# Há mudanças interessantes nos valores

# %%
base = base.fillna({'MasVnrType':'None'})

# %% [markdown]
# #### **3.6. Conclusão:**

# %% [markdown]
# ### **4. Tratando os valores nulos restantes**

# %%
base.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# FireplaceQu     690
# LotFrontage     259
# GarageType       81
# GarageCond       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# BsmtFinType2     38
# BsmtExposure     38
# BsmtFinType1     37
# BsmtCond         37
# BsmtQual         37
# MasVnrArea        8
# Electrical        1
# PavedDrive        0
# dtype: int64

# %% [markdown]
# #### **4.1. FireplaceQu**

# %% [markdown]
# - Po: Poor
# - Fa: Fair
# - TA: Typical/Average
# - Gd: Good
# - Ex: Excellent

# %%
base.fillna({'FireplaceQu':'Nulo'}).groupby('FireplaceQu')['SalePrice'].agg(['mean','count','min','max','std'])
# Out:
#                       mean  count     min     max            std
# FireplaceQu
# Ex           337712.500000     24  130500  755000  123611.471764
# Fa           167298.484848     33  117000  262000   34287.717564
# Gd           226351.415789    380   90350  611657   91123.148369
# Nulo         141331.482609    690   34900  342643   44389.786884
# Po           129764.150000     20   60000  172000   31080.842115
# TA           205723.488818    313   82500  745000   71367.028772

# %%
kde_violin(base, 'FireplaceQu', 'SalePrice')

# %%
base['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
base = base.fillna({'FireplaceQu':'No'})
base['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# No    690
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %% [markdown]
# #### **4.2. LotFrontage**
# - refere-se à frente do lote (lot frontage) de uma propriedade, medida em pés (feet). Essa variável representa a largura do terreno da casa ao longo da rua.

# %%
base[['LotFrontage','SalePrice']].corr()
# Out:
#              LotFrontage  SalePrice
# LotFrontage     1.000000   0.351799
# SalePrice       0.351799   1.000000

# %%
fig, ax = plt.subplots(ncols=2, figsize=(12,4.2))
ax[0].scatter(x=base['LotFrontage'], y=base['SalePrice'], s=4.5, color='darkblue')
sns.kdeplot(base['LotFrontage'],color='darkblue', ax=ax[1], fill=True)
ax[1].text(155, 0.0175,'Valores concentrados\n entre 50 e 100', ha='center', fontsize=8, color='darkblue', alpha=1, fontweight='bold')
ax[1].yaxis.set_visible(False)
ax[1].spines[['top','left','right']].set_visible(False)
ax[0].grid()
ax[1].set_xlabel('')
ax[0].set_ylabel('Preço da casa', color='darkgreen')
plt.suptitle('LotFrontage', fontsize=14)
plt.show()

# %%
bins = [0, 50, 75, 100, 150, float('inf')]
labels = ['0-50', '50-75', '75-100', '100-150', '150+']
base['Cut_LotFrontage'] = pd.cut(base['LotFrontage'], bins=bins, labels=labels, right=True)

# %%
fig, ax = plt.subplots(figsize=(8,4), tight_layout=True)
sns.violinplot(data=base, x='Cut_LotFrontage', y='SalePrice', color='darkblue')
ax.grid()
plt.show()

# %%
base['Cut_LotFrontage'].value_counts()
# Out:
# Cut_LotFrontage
# 50-75      581
# 75-100     331
# 0-50       205
# 100-150     75
# 150+         9
# Name: count, dtype: int64

# %%
base.groupby("Cut_LotFrontage", observed=True)['SalePrice'].agg(['mean','min','max','count','median','std'])
# Out:
#                           mean    min     max  count    median            std
# Cut_LotFrontage
# 0-50             152450.682927  35311  538000    205  140000.0   66228.987719
# 50-75            160457.944923  34900  501837    581  144000.0   62712.702919
# 75-100           214005.033233  82500  611657    331  193500.0   83028.317525
# 100-150          256746.666667  81000  755000     75  215000.0  131753.948771
# 150+             281691.666667  52500  745000      9  242000.0  198393.019030

# %%
base['LotFrontage'].isnull().sum()
# Out:
# np.int64(259)

# %%
cols_lot = base.loc[:, base.columns.str.contains("Lot")].columns.values
cols_lot
# Out:
# array(['LotFrontage', 'LotArea', 'LotShape', 'LotConfig',
#        'Cut_LotFrontage'], dtype=object)

# %%
base.groupby(['LotConfig','LotShape'])['LotFrontage'].agg(['mean','median','std'])
# Out:
#                           mean  median        std
# LotConfig LotShape
# Corner    IR1        97.448276    96.0  22.220721
#           IR2        96.000000    96.0  19.798990
#           IR3       247.500000   247.5  92.630988
#           Reg        75.920863    75.0  22.251222
# CulDSac   IR1        58.942857    50.0  21.794418
#           IR2        51.666667    49.0   7.842194
#           IR3       168.000000   168.0        NaN
#           Reg              NaN     NaN        NaN
# FR2       IR1        75.666667    77.0  18.184242
#           IR2        48.666667    48.0   8.020806
#           Reg        62.333333    64.5  20.660121
# FR3       IR1        60.000000    60.0        NaN
#           Reg        74.333333    59.0  48.839874
# Inside    IR1        73.239631    71.0  20.526128
#           IR2        98.833333    71.0  74.718664
#           IR3        76.500000    63.0  51.468437
#           Reg        65.369343    65.0  19.072176

# %%
base['LotFrontage'] = base.LotFrontage.fillna(base.groupby(['LotConfig','LotShape'])['LotFrontage'].transform('median'))

# %%
base = base.drop("Cut_LotFrontage",axis=1)

# %%
base.loc[base.LotFrontage.isnull()]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 660  661          60       RL          NaN    12384   Pave      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 660         Lvl    AllPub   CulDSac       Gtl       NWAmes       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 660       Norm     1Fam     2Story            7            7       1976
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 660          1976     Gable  CompShg     Plywood     Plywood    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 660       233.0        TA        TA     CBlock       Gd       TA           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 660          Unf           0          Unf           0        793          793
#
# ...

# %%
print(base.loc[base['LotConfig'] == 'CulDSac','LotFrontage'].median())
print(base.loc[base['LotShape'] == 'Reg','LotFrontage'].median())
# Out:
# 50.0
# 65.0

# %%
115/2
# Out:
# 57.5

# %%
base.loc[base['LotFrontage'].isnull(), 'LotFrontage'] = 57.5

# %% [markdown]
# #### **4.3. Garage columns**

# %%
base.isnull().sum().sort_values(ascending=False).head(15)
# Out:
# GarageType      81
# GarageCond      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# BsmtFinType2    38
# BsmtExposure    38
# BsmtFinType1    37
# BsmtCond        37
# BsmtQual        37
# MasVnrArea       8
# Electrical       1
# LotFrontage      1
# OpenPorchSF      0
# WoodDeckSF       0
# dtype: int64

# %%
valores_nulos_garagem = base.loc[base.GarageType.isnull(),base.columns.str.contains("Garage")]
valores_nulos_garagem = valores_nulos_garagem.fillna('NaN')
for i in valores_nulos_garagem:
    print(valores_nulos_garagem[i].value_counts())
# Out:
# GarageType
# NaN    81
# Name: count, dtype: int64
# GarageYrBlt
# NaN    81
# Name: count, dtype: int64
# GarageFinish
# NaN    81
# Name: count, dtype: int64
# GarageCars
# 0    81
# Name: count, dtype: int64
# GarageArea
# 0    81
# Name: count, dtype: int64
# GarageQual
# NaN    81
# Name: count, dtype: int64
# GarageCond
# NaN    81
# Name: count, dtype: int64

# %% [markdown]
# Esses valores nulos são devido as casas não terem garagens

# %%
base.loc[base.GarageCars == 0, ['GarageType','GarageFinish','GarageYrBlt','GarageQual','GarageCond']] = 0

base.loc[base.GarageCars == 0, ['GarageType','GarageFinish','GarageYrBlt','GarageQual','GarageCond']]
# Out:
#      GarageType GarageFinish  GarageYrBlt GarageQual GarageCond
# 39            0            0          0.0          0          0
# 48            0            0          0.0          0          0
# 78            0            0          0.0          0          0
# 88            0            0          0.0          0          0
# 89            0            0          0.0          0          0
# ...         ...          ...          ...        ...        ...
# 1349          0            0          0.0          0          0
# 1407          0            0          0.0          0          0
# 1449          0            0          0.0          0          0
# 1450          0            0          0.0          0          0
# 1453          0            0          0.0          0          0
#
# [81 rows x 5 columns]

# %% [markdown]
# #### **4.4. Bsmt columns**

# %% [markdown]
# - **BsmtQual** : Altura do porão
# - **BsmtCond** : Estado geral do porão
# - **BsmtExposure** : Paredes de porão no nível do jardim
# - **BsmtFinType1** : Qualidade da área acabada do porão
# - **BsmtFinSF1** : Pés quadrados acabados tipo 1
# - **BsmtFinType2** : Qualidade da segunda área acabada (se presente)
# - **BsmtFinSF2** : Tipo 2 pés quadrados acabados
# - **BsmtUnfSF** : Pés quadrados inacabados de área de subsolo

# %%
base.isnull().sum().sort_values(ascending=False).head(5)
# Out:
# BsmtExposure    38
# BsmtFinType2    38
# BsmtQual        37
# BsmtCond        37
# BsmtFinType1    37
# dtype: int64

# %%
base.loc[base.BsmtExposure.isnull(), base.columns.str.contains('Bsmt')].head(3)
# Out:
#    BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 17      NaN      NaN          NaN          NaN           0          NaN
# 39      NaN      NaN          NaN          NaN           0          NaN
# 90      NaN      NaN          NaN          NaN           0          NaN
#
#     BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath
# 17           0          0            0             0             0
# 39           0          0            0             0             0
# 90           0          0            0             0             0

# %%
base.loc[((base['BsmtQual'].isnull()) & 
         (base['BsmtCond'].isnull()) & 
         (base['BsmtExposure'].isnull()) & 
         (base['BsmtFinType1'].isnull()) & 
         (base['BsmtFinType2'].isnull())),
         ['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']] = 'No Bsmt'

# %%
base.isnull().sum().sort_values(ascending=False).head(8)
# Out:
# MasVnrArea      8
# BsmtExposure    1
# BsmtFinType2    1
# Electrical      1
# LotFrontage     1
# LowQualFinSF    0
# KitchenAbvGr    0
# FireplaceQu     0
# dtype: int64

# %%
base.loc[(base['BsmtExposure'].isnull()) | (base['BsmtFinType2'].isnull())]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 332  333          20       RL         85.0    10655   Pave      IR1
# 948  949          60       RL         65.0    14006   Pave      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 332         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 948         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 332       Norm     1Fam     1Story            8            5       2003
# 948       Norm     1Fam     2Story            7            5       2002
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 332          2004     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 948          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %%
base.BsmtExposure.value_counts()
# Out:
# BsmtExposure
# No         953
# Av         221
# Gd         134
# Mn         114
# No Bsmt     37
# Name: count, dtype: int64

# %%
base.BsmtFinType2.value_counts()
# Out:
# BsmtFinType2
# Unf        1256
# Rec          54
# LwQ          46
# No Bsmt      37
# BLQ          33
# ALQ          19
# GLQ          14
# Name: count, dtype: int64

# %%
base.loc[:, base.columns.str.contains('Bsmt')].head(3)
# Out:
#   BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 0       Gd       TA           No          GLQ         706          Unf
# 1       Gd       TA           Gd          ALQ         978          Unf
# 2       Gd       TA           Mn          GLQ         486          Unf
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath
# 0           0        150          856             1             0
# 1           0        284         1262             0             1
# 2           0        434          920             1             0

# %%
base.loc[((base['BsmtExposure'].isnull()) | (base['BsmtFinType2'].isnull())), base.columns.str.contains('Bsmt')]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 332       Gd       TA           No          GLQ        1124          NaN
# 948       Gd       TA          NaN          Unf           0          Unf
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath
# 332         479       1603         3206             1             0
# 948           0        936          936             0             0

# %%
base.loc[332, 'BsmtFinType2'] = 'ALQ'
base.loc[332, base.columns.str.contains('Bsmt')]
# Out:
# BsmtQual          Gd
# BsmtCond          TA
# BsmtExposure      No
# BsmtFinType1     GLQ
# BsmtFinSF1      1124
# BsmtFinType2     ALQ
# BsmtFinSF2       479
# BsmtUnfSF       1603
# TotalBsmtSF     3206
# BsmtFullBath       1
# BsmtHalfBath       0
# Name: 332, dtype: object

# %% [markdown]
# Agora o valor nulo de Exposure

# %%
base.loc[(base['BsmtExposure'].isnull()), base.columns.str.contains('Bsmt')]
# Out:
#     BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  \
# 948       Gd       TA          NaN          Unf           0          Unf
#
#      BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath
# 948           0        936          936             0             0

# %%
base.groupby(['BsmtQual','BsmtCond'])['BsmtExposure'].value_counts()
# Out:
# BsmtQual  BsmtCond  BsmtExposure
# Ex        Gd        No                7
#                     Av                2
#                     Gd                1
#                     Mn                1
#           TA        No               36
#                     Av               33
#                     Gd               33
#                     Mn                8
# Fa        Fa        No                6
#                     Mn                2
#           Po        Gd                1
#                     No                1
#           TA        No               22
#                     Mn                3
# Gd        Fa        No                2
#           Gd        No               19
#                     Av                9
#                     Gd                5
#                     Mn                3
#           TA        No              338
#                     Av              126
#                     Gd               64
# ...

# %%
base.loc[948, 'BsmtExposure'] = 'No'
base.loc[948, 'BsmtExposure']
# Out:
# 'No'

# %% [markdown]
# #### **4.5. Others**

# %%
base.isnull().sum().sort_values(ascending=False).head(3)
# Out:
# MasVnrArea    8
# Electrical    1
# Id            0
# dtype: int64

# %%
base.loc[base.MasVnrArea.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 234    235          60       RL         65.0     7851   Pave      Reg
# 529    530          20       RL         50.0    32668   Pave      IR1
# 650    651          60       FV         65.0     8125   Pave      Reg
# 936    937          20       RL         67.0    10083   Pave      Reg
# 973    974          20       FV         95.0    11639   Pave      Reg
# 977    978         120       FV         35.0     4274   Pave      IR1
# 1243  1244          20       RL        107.0    13891   Pave      Reg
# 1278  1279          60       RL         75.0     9473   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 234          Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 529          Lvl    AllPub   CulDSac       Gtl      Crawfor       Norm
# 650          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# ...

# %%
base.groupby('MasVnrType')['MasVnrArea'].median()
# Out:
# MasVnrType
# BrkCmn     192.0
# BrkFace    202.0
# None         0.0
# Stone      206.5
# Name: MasVnrArea, dtype: float64

# %%
base.loc[(base.MasVnrArea >0) & (base.MasVnrType == 'None')]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 624    625          60       RL         80.0    10400   Pave      Reg
# 773    774          20       RL         70.0    10150   Pave      Reg
# 1230  1231          90       RL         71.0    18890   Pave      IR1
# 1300  1301          60       RL         50.0    10762   Pave      IR1
# 1334  1335         160       RM         24.0     2368   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 624          Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 773          Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1230         Lvl    AllPub    Inside       Gtl       Sawyer      Feedr
# 1300         Lvl    AllPub   CulDSac       Gtl      Gilbert       Norm
# 1334         Lvl    AllPub    Inside       Gtl       BrDale       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
base.loc[base.MasVnrArea.isnull(), 'MasVnrArea'] = 0

# %%
base.isnull().sum().sort_values(ascending=False).head(3)
# Out:
# Electrical    1
# Id            0
# HalfBath      0
# dtype: int64

# %%
base.loc[base.Electrical.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1379  1380          80       RL         73.0     9735   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1379         Lvl    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1379       Norm     1Fam       SLvl            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1379          2007     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
base.groupby('CentralAir')['Electrical'].value_counts()
# Out:
# CentralAir  Electrical
# N           SBrkr           52
#             FuseA           22
#             FuseF           18
#             FuseP            3
# Y           SBrkr         1282
#             FuseA           72
#             FuseF            9
#             Mix              1
# Name: count, dtype: int64

# %%
base.loc[base.Electrical.isnull(), 'Electrical'] = 'SBrkr'

# %%
base.isnull().sum().sort_values(ascending=False).head()
# Out:
# Id             0
# HalfBath       0
# FireplaceQu    0
# Fireplaces     0
# Functional     0
# dtype: int64

# %%
base.to_csv('../data/train_notnull.csv',index=False)

# %% [markdown]
# ### **5. Conclusão:**
